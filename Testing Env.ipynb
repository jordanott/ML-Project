# %%
import numpy as np
import matplotlib.pyplot as plt
from src.environment import env_manager

env = env_manager.Environment()

# %%
plt.imshow(env.env.reshape(3542, 2479))
plt.show()

# %% [markdown]
# #### Parsing XML

# %%
for line in env.xml[1]:
    for word in line:
        if word.tag == 'word':
            print(word.attrib)
        elif word.tag == 'lower-contour':
            print('Lower contour',word[0].attrib,word[1].attrib)
        elif word.tag == 'upper-contour':
            print('Upper contour',word[0].attrib,word[1].attrib)
# Out:
# {'id': 'a01-000u-00-00', 'text': 'A', 'sentence-start': 'yes', 'tag': 'AT'}
# {'id': 'a01-000u-00-01', 'text': 'MOVE', 'tag': 'NN'}
# {'id': 'a01-000u-00-02', 'text': 'to', 'tag': 'TO'}
# {'id': 'a01-000u-00-03', 'text': 'stop', 'tag': 'VB'}
# {'id': 'a01-000u-00-04', 'text': 'Mr.', 'tag': 'NPT'}
# {'id': 'a01-000u-00-05', 'text': 'Gaitskell', 'tag': 'NP'}
# {'id': 'a01-000u-00-06', 'text': 'from', 'tag': 'IN'}
# Lower contour {'y': '835', 'x': '406'} {'y': '835', 'x': '2070'}
# {'id': 'a01-000u-01-00', 'text': 'nominating', 'tag': 'VBG'}
# {'id': 'a01-000u-01-01', 'text': 'any', 'tag': 'DTI'}
# {'id': 'a01-000u-01-02', 'text': 'more', 'tag': 'AP'}
# {'id': 'a01-000u-01-03', 'text': 'Labour', 'tag': 'NN'}
# {'id': 'a01-000u-01-04', 'text': 'life', 'tag': 'NN'}
# {'id': 'a01-000u-01-05', 'text': 'Peers', 'tag': 'NNS'}
# Upper contour {'y': '835', 'x': '406'} {'y': '835', 'x': '2070'}
# Lower contour {'y': '1036', 'x': '406'} {'y': '1036', 'x': '2246'}
# ...
